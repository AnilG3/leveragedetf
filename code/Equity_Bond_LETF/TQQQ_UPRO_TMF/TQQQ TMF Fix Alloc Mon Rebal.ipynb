# %%
"""
    Asset Allocation Model
    Two Leveraged ETFs with target weight
    Leverage ETFs: TQQQ, TMF
    Rebalancing: Monthly
"""
# %matplotlib inline

# silence warnings
import warnings
warnings.filterwarnings('ignore')

import zipline
from zipline.api import order_target_percent, symbol, schedule_function, date_rules, time_rules, set_benchmark, get_datetime
from datetime import datetime
import pytz
import pyfolio as pf
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt, ticker, rc
from scipy import stats

# %%
# Sector Map for ETFs
SECT_MAP = {'TMF': 'Long term Treasuries', 'UPRO':'S&P500', 'TQQQ':'Nasdaq'}

def initialize(context):
    # ETF and target weight
    context.securities = {
        'TQQQ': 0.60,
        'TMF': 0.40
    }

    set_benchmark(symbol('SPY'))

    # Schedule rebalance for once a month
    schedule_function(rebalance, date_rules.month_start(), time_rules.market_open())

# %%
def rebalance(context, data):
    
    # Monthly Rebalancing First of each Calendar Month
    # Loop through securities
    for sec, weight in context.securities.items():
        sym = symbol(sec)
        # check if we can trade
        if data.can_trade(sym):
            # reset the weight
            order_target_percent(sym, weight)

# %%
def month_perf(ts):
    perf = (ts[-1] / ts[0]) - 1
    return perf

# %%
def analyze(context, perf):
    # Extract algo and benchmark returns
    returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(perf)
    benchmark_period_return = perf['benchmark_period_return']
    
    # Convert benchmark returns to daily returns
    # daily_returns = (1 + benchmark_period_return) / (1 + benchmark_period_return.shift()) - 1
    daily_benchmark_returns = np.exp(np.log(benchmark_period_return + 1.0).diff()) - 1
    
    # Create tear sheet
    # Note: Live start date is Bogleheads forum HEDGEFUNDIE's post start date https://www.bogleheads.org/forum/viewtopic.php?f=10&t=272007
    pf.create_full_tear_sheet(live_start_date = '2019-02-05', returns = returns, positions = positions, transactions = transactions, round_trips = False, benchmark_rets = daily_benchmark_returns,  sector_mappings=SECT_MAP)
    # Note: The round trip tear sheet is done separately at the bottom. The error interferes with execution of the rest of the program.

# %%
# set start and end date
start = pd.to_datetime('2010-02-11', utc=True)
end = pd.to_datetime('2021-06-04', utc=True)

# start backtest
result = zipline.run_algorithm(
    start = start, 
    end = end, 
    initialize = initialize,
    analyze = analyze,
    capital_base = 10000, 
    data_frequency = 'daily', 
    bundle = 'etf_db_data')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=4>2010-02-11</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=4>2021-06-04</td></tr>
#     <tr style="text-align: right;"><th>In-sample months</th><td colspan=4>107</td></tr>
#     <tr style="text-align: right;"><th>Out-of-sample months</th><td colspan=4>28</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>In-sample</th>
#       <th>Out-of-sample</th>
#       <th>All</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>38.134%</td>
#       <td>73.035%</td>
#       <td>44.71%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>1712.408%</td>
#       <td>259.459%</td>
#       <td>6414.854%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>27.522%</td>
#       <td>43.327%</td>
#       <td>31.442%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.31</td>
#       <td>1.49</td>
#       <td>1.33</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>1.07</td>
#       <td>1.54</td>
#       <td>0.95</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.98</td>
#       <td>0.93</td>
#       <td>0.98</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-35.791%</td>
#       <td>-47.281%</td>
#       <td>-47.281%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.25</td>
#       <td>1.30</td>
#       <td>1.26</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.89</td>
#       <td>2.10</td>
#       <td>1.91</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.34</td>
#       <td>-0.58</td>
#       <td>-0.46</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>1.51</td>
#       <td>3.98</td>
#       <td>4.24</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.98</td>
#       <td>0.94</td>
#       <td>1.02</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-3.324%</td>
#       <td>-5.203%</td>
#       <td>-3.795%</td>
#     </tr>
#     <tr>
#       <th>Gross leverage</th>
#       <td>1.00</td>
#       <td>1.00</td>
#       <td>1.00</td>
#     </tr>
#     <tr>
#       <th>Daily turnover</th>
#       <td>0.471%</td>
#       <td>0.508%</td>
#       <td>0.479%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.21</td>
#       <td>0.43</td>
#       <td>0.25</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>1.25</td>
#       <td>1.23</td>
#       <td>1.24</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>47.28</td>
#       <td>2020-02-19</td>
#       <td>2020-03-18</td>
#       <td>2020-05-20</td>
#       <td>66</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>35.79</td>
#       <td>2018-08-29</td>
#       <td>2018-12-24</td>
#       <td>2019-04-05</td>
#       <td>158</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>26.14</td>
#       <td>2021-01-25</td>
#       <td>2021-03-08</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>25.12</td>
#       <td>2020-09-02</td>
#       <td>2020-10-30</td>
#       <td>2021-01-20</td>
#       <td>101</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>22.56</td>
#       <td>2015-04-24</td>
#       <td>2015-09-29</td>
#       <td>2015-12-01</td>
#       <td>158</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>US downgrade/European Debt Crisis</th>
#       <td>0.25%</td>
#       <td>-5.26%</td>
#       <td>6.55%</td>
#     </tr>
#     <tr>
#       <th>Fukushima</th>
#       <td>0.15%</td>
#       <td>-2.88%</td>
#       <td>2.36%</td>
#     </tr>
#     <tr>
#       <th>EZB IR Event</th>
#       <td>-0.33%</td>
#       <td>-3.39%</td>
#       <td>2.09%</td>
#     </tr>
#     <tr>
#       <th>Flash Crash</th>
#       <td>-0.73%</td>
#       <td>-6.04%</td>
#       <td>4.15%</td>
#     </tr>
#     <tr>
#       <th>Apr14</th>
#       <td>0.16%</td>
#       <td>-4.22%</td>
#       <td>2.34%</td>
#     </tr>
#     <tr>
#       <th>Oct14</th>
#       <td>0.33%</td>
#       <td>-3.49%</td>
#       <td>3.41%</td>
#     </tr>
#     <tr>
#       <th>Fall2015</th>
#       <td>-0.50%</td>
#       <td>-6.52%</td>
#       <td>4.43%</td>
#     </tr>
#     <tr>
#       <th>Recovery</th>
#       <td>0.17%</td>
#       <td>-6.04%</td>
#       <td>6.74%</td>
#     </tr>
#     <tr>
#       <th>New Normal</th>
#       <td>0.17%</td>
#       <td>-14.03%</td>
#       <td>12.28%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 long positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>TQQQ</th>
#       <td>77.21%</td>
#     </tr>
#     <tr>
#       <th>TMF</th>
#       <td>64.41%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 short positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>TQQQ</th>
#       <td>77.21%</td>
#     </tr>
#     <tr>
#       <th>TMF</th>
#       <td>64.41%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Performance Analysis - Pyfolio Returns Tear Sheet
#returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(result)
#pf.create_full_tear_sheet(returns, positions = positions, transactions = transactions, round_trips = True, 
#                          benchmark_rets = None)
#pf.create_returns_tear_sheet(returns, benchmark_rets = None)

# %%
# Analytics - Annualized Return and Maximum drawdown

# settings
window = 252
year_length = 252

# copy needed columns
df = result.copy().filter(items=['portfolio_value', 'gross_leverage', 'returns'])

# Annualized Return = (End Value / Start Value) ** (Year Days / Actual Days) - 1
def ann_ret(ts):
    return np.power((ts[-1] / ts[0]), (year_length / len(ts))) - 1

# Maximum drawdown
def dd(ts):
    return np.min(ts / np.maximum.accumulate(ts)) - 1

# rolling window
rolling_window = result.portfolio_value.rolling(window)

# rolling analytics
df['annualized'] = rolling_window.apply(ann_ret)
df['drawdown'] = rolling_window.apply(dd)

# drop initial n/a
df.dropna(inplace = True)

# Figure
fig = plt.figure(figsize = (15, 12))

# Reduce base for easy readability
df['portfolio_value'] /= 100

# First chart
ax = fig.add_subplot(511)
ax.set_title('Strategy Results')
ax.plot(df['portfolio_value'], linestyle = '-', color = 'black', label = 'Equity Curve', linewidth = 3.0)

# log scale
ax.set_yscale('log')

# prettier axis
ax.yaxis.set_ticks(np.arange(df['portfolio_value'].min(), df['portfolio_value'].max(), 500))
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%0.0f'))

# legend and grid
ax.legend()
ax.grid(False)

# Second chart
ax = fig.add_subplot(512)
ax.plot(df['gross_leverage'], 
        linestyle = '-', color = 'black', label = 'Strategy Exposure'.format(window), linewidth = 1.0)

# prettier axis
ax.yaxis.set_ticks(np.arange(df['gross_leverage'].min(), df['gross_leverage'].max(), 0.01 ))
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%0.2f'))

# legend and grid
ax.legend()
ax.grid(True)

# Third chart
ax = fig.add_subplot(513)
ax.plot(df['annualized'], 
        linestyle = '-', color = 'black', label = '{} days annualized return'.format(window), linewidth = 1.0)
ax.axhline(df['annualized'].mean(), color='black', linewidth=1.5, label='Mean {:0.1f}%'.format(df['annualized'].mean() * 100))

# prettier axis
ax.yaxis.set_ticks(np.arange(df['annualized'].min(), df['annualized'].max(), 0.2))
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%0.2f'))

# legend and grid
ax.legend()
ax.grid(True)

# Fourth chart
ax = fig.add_subplot(514)
ax.plot(df['drawdown'], 
        linestyle = '-', color = 'black', label = '{} days max drawdown'.format(window), linewidth = 1.0)

# prettier axis
ax.yaxis.set_ticks(np.arange(df['drawdown'].min(), df['drawdown'].max(), 0.05))
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%0.2f'))

# legend and grid
ax.legend()
ax.grid(True)

# Fifth chart
ax = fig.add_subplot(515)
ax.plot(df['returns'], label = 'Daily Returns', linestyle = '-', linewidth = 1.0)

ax.legend()
ax.grid(True)

# %%
"""
    Monthly Time Return Table
"""


# Used for performance calculations
import empyrical as em

# Used for displaying HTML formatted content in notebook
from IPython.core.display import display, HTML

# Use Empyrical to aggregate on monthly and yearly periods
monthly_data = em.aggregate_returns(result['portfolio_value'].pct_change(), 'monthly')
yearly_data = em.aggregate_returns(result['portfolio_value'].pct_change(), 'yearly')

# Start off an HTML table for display
# HTML Table for display
table = """
<table class='table table-hover table-condensed table-striped'>
<thead>
<tr>
<th style="text-align:right">Year</th>
<th style="text-align:right">Jan</th>
<th style="text-align:right">Feb</th>
<th style="text-align:right">Mar</th>
<th style="text-align:right">Apr</th>
<th style="text-align:right">May</th>
<th style="text-align:right">Jun</th>
<th style="text-align:right">Jul</th>
<th style="text-align:right">Aug</th>
<th style="text-align:right">Sep</th>
<th style="text-align:right">Oct</th>
<th style="text-align:right">Nov</th>
<th style="text-align:right">Dec</th>
<th style="text-align:right">Year</th>
</tr>
</thead>
<tbody>
<tr>"""

# initialize
first_year = True
first_month = True
yr = 0
mnth = 0

# iterate over pandas series
for m, val in monthly_data.iteritems():
    yr = m[0]
    mnth = m[1]
    
    # first month of year, add year label to table
    if (first_month):
        table += "<td align='right'><b>{}</b></td>\n".format(yr)
        first_month = False
    
    # pad empty months for first year if simulation starts later in year
    if (first_year):
        first_year = False
        if (mnth > 1):
            for i in range(1, mnth):
                table += "<td align='right'>-</td>\n"
                
    # add monthly performance
    table += "<td align='right'>{:+.1f}</td>\n".format(val * 100)
    
    # check for 12th month, add annual return number
    if (mnth == 12):
        table += "<td align='right'><b>{:+.1f}</b></td>\n".format(yearly_data[yr] * 100)
        table += '</tr>\n<tr>\n'
        first_month = True
        
# pad empty months for last year
if (mnth != 12):
    for i in range(mnth + 1, 13):
        table +="<td align='right'><b>\n"
        if (i == 12):
            table += "<td align='right'><b>{:+.1f}</b></td>\n".format(yearly_data[yr] * 100)
            table += '</tr>\n<tr>\n'

# finalize table
table += '</tr>\n</tbody>\n</table>'

display(HTML(table))
# Out:
# <table class='table table-hover table-condensed table-striped'>
# <thead>
# <tr>
# <th style="text-align:right">Year</th>
# <th style="text-align:right">Jan</th>
# <th style="text-align:right">Feb</th>
# <th style="text-align:right">Mar</th>
# <th style="text-align:right">Apr</th>
# <th style="text-align:right">May</th>
# <th style="text-align:right">Jun</th>
# <th style="text-align:right">Jul</th>
# <th style="text-align:right">Aug</th>
# <th style="text-align:right">Sep</th>
# <th style="text-align:right">Oct</th>
# <th style="text-align:right">Nov</th>
# <th style="text-align:right">Dec</th>
# <th style="text-align:right">Year</th>
# </tr>
# </thead>
# <tbody>
# <tr><td align='right'><b>2010</b></td>
# <td align='right'>-</td>
# <td align='right'>+0.0</td>
# <td align='right'>+8.7</td>
# <td align='right'>+8.1</td>
# <td align='right'>-6.7</td>
# <td align='right'>-5.8</td>
# <td align='right'>+11.6</td>
# <td align='right'>+2.8</td>
# <td align='right'>+18.3</td>
# <td align='right'>+6.0</td>
# <td align='right'>-3.3</td>
# <td align='right'>+4.1</td>
# <td align='right'><b>+49.7</b></td>
# </tr>
# <tr>
# <td align='right'><b>2011</b></td>
# <td align='right'>+1.1</td>
# <td align='right'>+7.5</td>
# <td align='right'>-1.6</td>
# <td align='right'>+7.7</td>
# <td align='right'>+1.5</td>
# <td align='right'>-7.0</td>
# <td align='right'>+8.3</td>
# <td align='right'>-0.4</td>
# <td align='right'>+10.0</td>
# <td align='right'>+16.7</td>
# <td align='right'>-5.7</td>
# <td align='right'>+2.2</td>
# <td align='right'><b>+45.0</b></td>
# </tr>
# <tr>
# <td align='right'><b>2012</b></td>
# <td align='right'>+14.6</td>
# <td align='right'>+8.9</td>
# <td align='right'>+3.9</td>
# <td align='right'>+3.6</td>
# <td align='right'>-0.5</td>
# <td align='right'>+5.9</td>
# <td align='right'>+6.1</td>
# <td align='right'>+7.8</td>
# <td align='right'>-1.9</td>
# <td align='right'>-10.3</td>
# <td align='right'>+3.4</td>
# <td align='right'>-4.2</td>
# <td align='right'><b>+41.1</b></td>
# </tr>
# <tr>
# <td align='right'><b>2013</b></td>
# <td align='right'>+0.9</td>
# <td align='right'>+1.7</td>
# <td align='right'>+4.5</td>
# <td align='right'>+9.7</td>
# <td align='right'>-1.1</td>
# <td align='right'>-8.9</td>
# <td align='right'>+9.1</td>
# <td align='right'>-2.3</td>
# <td align='right'>+9.4</td>
# <td align='right'>+10.5</td>
# <td align='right'>+2.9</td>
# <td align='right'>+2.9</td>
# <td align='right'><b>+44.4</b></td>
# </tr>
# <tr>
# <td align='right'><b>2014</b></td>
# <td align='right'>+3.6</td>
# <td align='right'>+10.7</td>
# <td align='right'>-4.2</td>
# <td align='right'>+1.3</td>
# <td align='right'>+11.9</td>
# <td align='right'>+5.3</td>
# <td align='right'>+2.8</td>
# <td align='right'>+15.1</td>
# <td align='right'>-4.3</td>
# <td align='right'>+7.4</td>
# <td align='right'>+12.2</td>
# <td align='right'>-0.8</td>
# <td align='right'><b>+77.5</b></td>
# </tr>
# <tr>
# <td align='right'><b>2015</b></td>
# <td align='right'>+8.5</td>
# <td align='right'>+5.3</td>
# <td align='right'>-2.5</td>
# <td align='right'>-0.7</td>
# <td align='right'>+1.2</td>
# <td align='right'>-9.5</td>
# <td align='right'>+13.5</td>
# <td align='right'>-14.0</td>
# <td align='right'>-3.1</td>
# <td align='right'>+21.6</td>
# <td align='right'>+0.3</td>
# <td align='right'>-4.4</td>
# <td align='right'><b>+11.7</b></td>
# </tr>
# <tr>
# <td align='right'><b>2016</b></td>
# <td align='right'>-6.2</td>
# <td align='right'>+0.7</td>
# <td align='right'>+11.5</td>
# <td align='right'>-6.6</td>
# <td align='right'>+8.3</td>
# <td align='right'>+3.7</td>
# <td align='right'>+16.7</td>
# <td align='right'>+0.6</td>
# <td align='right'>+1.6</td>
# <td align='right'>-8.0</td>
# <td align='right'>-8.8</td>
# <td align='right'>+0.9</td>
# <td align='right'><b>+11.3</b></td>
# </tr>
# <tr>
# <td align='right'><b>2017</b></td>
# <td align='right'>+10.0</td>
# <td align='right'>+9.9</td>
# <td align='right'>+2.5</td>
# <td align='right'>+6.7</td>
# <td align='right'>+9.0</td>
# <td align='right'>-4.0</td>
# <td align='right'>+6.6</td>
# <td align='right'>+7.0</td>
# <td align='right'>-3.6</td>
# <td align='right'>+8.0</td>
# <td align='right'>+3.9</td>
# <td align='right'>+2.7</td>
# <td align='right'><b>+75.3</b></td>
# </tr>
# <tr>
# <td align='right'><b>2018</b></td>
# <td align='right'>+12.2</td>
# <td align='right'>-7.6</td>
# <td align='right'>-5.0</td>
# <td align='right'>-2.5</td>
# <td align='right'>+12.4</td>
# <td align='right'>+2.2</td>
# <td align='right'>+2.6</td>
# <td align='right'>+12.1</td>
# <td align='right'>-4.5</td>
# <td align='right'>-19.5</td>
# <td align='right'>+0.1</td>
# <td align='right'>-8.3</td>
# <td align='right'><b>-10.7</b></td>
# </tr>
# <tr>
# <td align='right'><b>2019</b></td>
# <td align='right'>+18.0</td>
# <td align='right'>+3.6</td>
# <td align='right'>+13.6</td>
# <td align='right'>+6.9</td>
# <td align='right'>-6.3</td>
# <td align='right'>+14.8</td>
# <td align='right'>+4.1</td>
# <td align='right'>+8.9</td>
# <td align='right'>-2.5</td>
# <td align='right'>+5.7</td>
# <td align='right'>+6.9</td>
# <td align='right'>+2.6</td>
# <td align='right'><b>+104.5</b></td>
# </tr>
# <tr>
# <td align='right'><b>2020</b></td>
# <td align='right'>+14.2</td>
# <td align='right'>-3.5</td>
# <td align='right'>-16.2</td>
# <td align='right'>+34.8</td>
# <td align='right'>+8.5</td>
# <td align='right'>+11.4</td>
# <td align='right'>+18.8</td>
# <td align='right'>+14.5</td>
# <td align='right'>-10.3</td>
# <td align='right'>-10.1</td>
# <td align='right'>+22.5</td>
# <td align='right'>+8.8</td>
# <td align='right'><b>+120.0</b></td>
# </tr>
# <tr>
# <td align='right'><b>2021</b></td>
# <td align='right'>-4.5</td>
# <td align='right'>-7.1</td>
# <td align='right'>-5.0</td>
# <td align='right'>+13.5</td>
# <td align='right'>-3.1</td>
# <td align='right'>+2.3</td>
# <td align='right'><b>
# <td align='right'><b>
# <td align='right'><b>
# <td align='right'><b>
# <td align='right'><b>
# <td align='right'><b>
# <td align='right'><b>-5.3</b></td>
# </tr>
# <tr>
# </tr>
# </tbody>
# </table>

# %%
"""
    Holding period table

    Shows percentage return if you started in January of a given year and held for certain number of full years.
    In Table you can see what would have happened if you strated this strategy at a given year, and kept trading it
    for number of years from that point. This can be a useful way to quickly get an overview of how the initial
    starting time sometimes can matter quite a lot for a trading model. The numbers show annualized return over
    the number of years displayed on the x-axis.
"""


def holding_period_map(df):
    
    # agreegate yearly data
    yr = em.aggregate_returns(result['portfolio_value'].pct_change(), 'yearly')
    df = pd.DataFrame(columns=range(1,len(yr)+1), index=yr.index)

    yr_start = 0
    
    # start table
    table = "<table class='table table-hover table-condensed table-striped'>"
    table += "<tr><th>Years</th>"
    
    # build first row
    for i in range(len(yr)):
        table += "<th>{}</th>".format(i+1)
    table += "</tr>"

    # iterate years
    for the_year, value in yr.iteritems():
        # new table row
        table += "<tr><th>{}</th>".format(the_year)
        
        # iterate years held
        for yrs_held in (range(1, len(yr)+1)):
            if yrs_held   <= len(yr[yr_start:yr_start + yrs_held]):
                ret = em.annual_return(yr[yr_start:yr_start + yrs_held], 'yearly' )
                table += "<td>{:+.1f}</td>".format(ret * 100)
        table += "</tr>"    
        yr_start+=1
    return table

table = holding_period_map(df)
display(HTML(table))
# Out:
# <table class='table table-hover table-condensed table-striped'><tr><th>Years</th><th>1</th><th>2</th><th>3</th><th>4</th><th>5</th><th>6</th><th>7</th><th>8</th><th>9</th><th>10</th><th>11</th><th>12</th></tr><tr><th>2010</th><td>+49.7</td><td>+47.3</td><td>+45.2</td><td>+45.0</td><td>+51.0</td><td>+43.6</td><td>+38.5</td><td>+42.6</td><td>+35.4</td><td>+41.1</td><td>+46.9</td><td>+41.6</td></tr><tr><th>2011</th><td>+45.0</td><td>+43.1</td><td>+43.5</td><td>+51.3</td><td>+42.4</td><td>+36.7</td><td>+41.6</td><td>+33.7</td><td>+40.2</td><td>+46.6</td><td>+40.9</td></tr><tr><th>2012</th><td>+41.1</td><td>+42.7</td><td>+53.5</td><td>+41.8</td><td>+35.1</td><td>+41.1</td><td>+32.2</td><td>+39.6</td><td>+46.8</td><td>+40.5</td></tr><tr><th>2013</th><td>+44.4</td><td>+60.1</td><td>+42.0</td><td>+33.6</td><td>+41.1</td><td>+30.7</td><td>+39.4</td><td>+47.5</td><td>+40.5</td></tr><tr><th>2014</th><td>+77.5</td><td>+40.8</td><td>+30.2</td><td>+40.2</td><td>+28.1</td><td>+38.5</td><td>+48.0</td><td>+40.0</td></tr><tr><th>2015</th><td>+11.7</td><td>+11.5</td><td>+29.7</td><td>+18.1</td><td>+31.8</td><td>+43.6</td><td>+35.3</td></tr><tr><th>2016</th><td>+11.3</td><td>+39.7</td><td>+20.3</td><td>+37.4</td><td>+51.0</td><td>+39.7</td></tr><tr><th>2017</th><td>+75.3</td><td>+25.1</td><td>+47.4</td><td>+62.9</td><td>+46.2</td></tr><tr><th>2018</th><td>-10.7</td><td>+35.2</td><td>+59.0</td><td>+39.7</td></tr><tr><th>2019</th><td>+104.5</td><td>+112.1</td><td>+62.1</td></tr><tr><th>2020</th><td>+120.0</td><td>+44.4</td></tr><tr><th>2021</th><td>-5.3</td></tr>

# %%
# Create Round Trip Tear Sheet
# It generates ValueError: Axis limits cannot be NaN or Inf, that stops processing of rest of the code

returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(result)
pf.create_round_trip_tear_sheet(returns, positions, transactions, sector_mappings=SECT_MAP)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Summary stats</th>
#       <th>All trades</th>
#       <th>Long trades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Total number of round_trips</th>
#       <td>137.00</td>
#       <td>137.00</td>
#     </tr>
#     <tr>
#       <th>Percent profitable</th>
#       <td>0.92</td>
#       <td>0.92</td>
#     </tr>
#     <tr>
#       <th>Winning round_trips</th>
#       <td>126.00</td>
#       <td>126.00</td>
#     </tr>
#     <tr>
#       <th>Losing round_trips</th>
#       <td>11.00</td>
#       <td>11.00</td>
#     </tr>
#     <tr>
#       <th>Even round_trips</th>
#       <td>0.00</td>
#       <td>0.00</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>PnL stats</th>
#       <th>All trades</th>
#       <th>Long trades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Total profit</th>
#       <td>$641588.15</td>
#       <td>$641588.15</td>
#     </tr>
#     <tr>
#       <th>Gross profit</th>
#       <td>$745784.33</td>
#       <td>$745784.33</td>
#     </tr>
#     <tr>
#       <th>Gross loss</th>
#       <td>$-104196.18</td>
#       <td>$-104196.18</td>
#     </tr>
#     <tr>
#       <th>Profit factor</th>
#       <td>$7.16</td>
#       <td>$7.16</td>
#     </tr>
#     <tr>
#       <th>Avg. trade net profit</th>
#       <td>$4683.13</td>
#       <td>$4683.13</td>
#     </tr>
#     <tr>
#       <th>Avg. winning trade</th>
#       <td>$5918.92</td>
#       <td>$5918.92</td>
#     </tr>
#     <tr>
#       <th>Avg. losing trade</th>
#       <td>$-9472.38</td>
#       <td>$-9472.38</td>
#     </tr>
#     <tr>
#       <th>Ratio Avg. Win:Avg. Loss</th>
#       <td>$0.62</td>
#       <td>$0.62</td>
#     </tr>
#     <tr>
#       <th>Largest winning trade</th>
#       <td>$277504.23</td>
#       <td>$277504.23</td>
#     </tr>
#     <tr>
#       <th>Largest losing trade</th>
#       <td>$-94960.42</td>
#       <td>$-94960.42</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Duration stats</th>
#       <th>All trades</th>
#       <th>Long trades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avg duration</th>
#       <td>742 days 21:10:56.948905104</td>
#       <td>742 days 21:10:56.948905104</td>
#     </tr>
#     <tr>
#       <th>Median duration</th>
#       <td>700 days 00:00:00</td>
#       <td>700 days 00:00:00</td>
#     </tr>
#     <tr>
#       <th>Longest duration</th>
#       <td>1336 days 23:00:00</td>
#       <td>1336 days 23:00:00</td>
#     </tr>
#     <tr>
#       <th>Shortest duration</th>
#       <td>33 days 23:00:00</td>
#       <td>33 days 23:00:00</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Return stats</th>
#       <th>All trades</th>
#       <th>Long trades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avg returns all round_trips</th>
#       <td>2.13%</td>
#       <td>2.13%</td>
#     </tr>
#     <tr>
#       <th>Avg returns winning</th>
#       <td>2.49%</td>
#       <td>2.49%</td>
#     </tr>
#     <tr>
#       <th>Avg returns losing</th>
#       <td>-2.01%</td>
#       <td>-2.01%</td>
#     </tr>
#     <tr>
#       <th>Median returns all round_trips</th>
#       <td>1.58%</td>
#       <td>1.58%</td>
#     </tr>
#     <tr>
#       <th>Median returns winning</th>
#       <td>1.67%</td>
#       <td>1.67%</td>
#     </tr>
#     <tr>
#       <th>Median returns losing</th>
#       <td>-0.42%</td>
#       <td>-0.42%</td>
#     </tr>
#     <tr>
#       <th>Largest winning trade</th>
#       <td>44.55%</td>
#       <td>44.55%</td>
#     </tr>
#     <tr>
#       <th>Largest losing trade</th>
#       <td>-15.24%</td>
#       <td>-15.24%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Symbol stats</th>
#       <th>TMF</th>
#       <th>TQQQ</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avg returns all round_trips</th>
#       <td>1.78%</td>
#       <td>2.36%</td>
#     </tr>
#     <tr>
#       <th>Avg returns winning</th>
#       <td>1.93%</td>
#       <td>2.87%</td>
#     </tr>
#     <tr>
#       <th>Avg returns losing</th>
#       <td>-0.79%</td>
#       <td>-2.46%</td>
#     </tr>
#     <tr>
#       <th>Median returns all round_trips</th>
#       <td>1.44%</td>
#       <td>1.67%</td>
#     </tr>
#     <tr>
#       <th>Median returns winning</th>
#       <td>1.49%</td>
#       <td>1.79%</td>
#     </tr>
#     <tr>
#       <th>Median returns losing</th>
#       <td>-0.45%</td>
#       <td>-0.33%</td>
#     </tr>
#     <tr>
#       <th>Largest winning trade</th>
#       <td>9.75%</td>
#       <td>44.55%</td>
#     </tr>
#     <tr>
#       <th>Largest losing trade</th>
#       <td>-1.89%</td>
#       <td>-15.24%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Profitability (PnL / PnL total) per name</th>
#       <th></th>
#     </tr>
#     <tr>
#       <th>symbol</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>TQQQ</th>
#       <td>99.16%</td>
#     </tr>
#     <tr>
#       <th>TMF</th>
#       <td>0.84%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Profitability (PnL / PnL total) per name</th>
#       <th></th>
#     </tr>
#     <tr>
#       <th>symbol</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>No Sector Mapping</th>
#       <td>100.00%</td>
#     </tr>
#   </tbody>
# </table>
