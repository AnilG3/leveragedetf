# %%
"""
    Asset Allocation Model
    Two Leveraged ETFs with target weight
    Leverage ETFs: UPRO, TMF
    Rebalancing: Quarterly
"""
# %matplotlib inline

# silence warnings
import warnings
warnings.filterwarnings('ignore')

import zipline
from zipline.api import order_target_percent, symbol, schedule_function, date_rules, time_rules, set_benchmark, get_datetime
from datetime import datetime
import pytz
import pyfolio as pf
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt, ticker, rc
from scipy import stats

# %%
# Rebalance at start of calendar quarter
QUARTER_STARTS = [1, 4, 7, 10]

def initialize(context):
    # ETFs and target weight
    context.securities = {
        'UPRO': 0.60,
        'TMF': 0.40
    }
    
    set_benchmark(symbol('SPY'))
    
    # setting a flag for first time purchase at portfolio initiation
    context.has_ordered = False
    
    # schedule rebalance once a quarter
    schedule_function(rebalance, date_rules.month_start(), time_rules.market_open())

# %%
def rebalance(context, data):
    
    # Quarterly Rebalcing First of each Calendar Quarter
    # If the current month number is not in QUARTER_STARTS,
    # don't do anything.
    month_number = get_datetime().date().month
    if context.has_ordered and month_number not in QUARTER_STARTS:
        return

    # Otherwise, execute rebalance
    # Loop thru ETFs
    for sec, weight in context.securities.items():
        sym = symbol(sec)
        # check if can trade
        if data.can_trade(sym):
            # Reset weight
            order_target_percent(sym, weight)
            
    # Set flag after the first order at portfolio creation
    context.has_ordered = True

# %%
def analyze(context, result=None):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    result.portfolio_value.plot(ax=ax)
    ax.set_ylabel('Portfolio value (USD)')
    plt.show()

# %%
# Set start and end
start = pd.to_datetime('2009-06-25', utc=True)
end = pd.to_datetime('2021-06-04', utc=True)

# Fire off backtest
result = zipline.run_algorithm(
    start = start, 
    end = end, 
    initialize = initialize,
    analyze = analyze,
    capital_base = 10000, 
    data_frequency = 'daily', 
    bundle = 'etf_db_data'
)

# %%
# Extract algo and benchmark returns
returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(result)
benchmark_period_return = result['benchmark_period_return']

# Convert benchmark returns to daily returns
# daily_returns = (1 + benchmark_period_return) / (1 + benchmark_period_return.shift()) - 1
benchmark_rets = np.exp(np.log(benchmark_period_return + 1.0).diff()) - 1

# Create tear sheet
# Note: Live start date is Bogleheads forum HEDGEFUNDIE's post start date https://www.bogleheads.org/forum/viewtopic.php?f=10&t=272007
pf.create_full_tear_sheet(
    returns,
    positions = positions,
    transactions = transactions,
    benchmark_rets = benchmark_rets,
    slippage = 0,
    live_start_date = '2019-02-05',
    round_trips = False,
    cone_std = (1.0, 1.5, 2.0), #Std deviation for cone plots
    bootstrap = True
)

# Note: The round trip tear sheet is done separately at the bottom. The error interferes with execution of the rest of the program.
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=14>2009-06-25</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=14>2021-06-04</td></tr>
#     <tr style="text-align: right;"><th>In-sample months</th><td colspan=14>115</td></tr>
#     <tr style="text-align: right;"><th>Out-of-sample months</th><td colspan=14>28</td></tr>
#     <tr>
#       <th></th>
#       <th colspan="4" halign="left">In-sample</th>
#       <th colspan="4" halign="left">Out-of-sample</th>
#       <th colspan="4" halign="left">All</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>mean</th>
#       <th>median</th>
#       <th>5%</th>
#       <th>95%</th>
#       <th>mean</th>
#       <th>median</th>
#       <th>5%</th>
#       <th>95%</th>
#       <th>mean</th>
#       <th>median</th>
#       <th>5%</th>
#       <th>95%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>34.94%</td>
#       <td>34.356%</td>
#       <td>18.753%</td>
#       <td>51.984%</td>
#       <td>68.87%</td>
#       <td>65.296%</td>
#       <td>9.96%</td>
#       <td>143.076%</td>
#       <td>40.273%</td>
#       <td>40.019%</td>
#       <td>22.808%</td>
#       <td>58.438%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>2157.56%</td>
#       <td>1637.871%</td>
#       <td>393.707%</td>
#       <td>5585.225%</td>
#       <td>256.431%</td>
#       <td>207.858%</td>
#       <td>20.278%</td>
#       <td>666.496%</td>
#       <td>7840.09%</td>
#       <td>5175.393%</td>
#       <td>972.942%</td>
#       <td>22321.528%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>23.519%</td>
#       <td>23.512%</td>
#       <td>22.727%</td>
#       <td>24.312%</td>
#       <td>36.964%</td>
#       <td>36.961%</td>
#       <td>32.845%</td>
#       <td>41.521%</td>
#       <td>26.723%</td>
#       <td>26.692%</td>
#       <td>25.524%</td>
#       <td>28.094%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.38</td>
#       <td>1.37</td>
#       <td>0.82</td>
#       <td>1.92</td>
#       <td>1.51</td>
#       <td>1.49</td>
#       <td>0.41</td>
#       <td>2.71</td>
#       <td>1.40</td>
#       <td>1.40</td>
#       <td>0.91</td>
#       <td>1.92</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>1.30</td>
#       <td>1.19</td>
#       <td>0.48</td>
#       <td>2.45</td>
#       <td>2.65</td>
#       <td>2.03</td>
#       <td>0.20</td>
#       <td>7.17</td>
#       <td>1.20</td>
#       <td>1.12</td>
#       <td>0.51</td>
#       <td>2.12</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.94</td>
#       <td>0.96</td>
#       <td>0.82</td>
#       <td>0.99</td>
#       <td>0.74</td>
#       <td>0.85</td>
#       <td>0.11</td>
#       <td>0.97</td>
#       <td>0.95</td>
#       <td>0.96</td>
#       <td>0.86</td>
#       <td>0.99</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-30.272%</td>
#       <td>-29.079%</td>
#       <td>-43.89%</td>
#       <td>-20.866%</td>
#       <td>-32.651%</td>
#       <td>-31.307%</td>
#       <td>-50.379%</td>
#       <td>-18.982%</td>
#       <td>-36.338%</td>
#       <td>-35.103%</td>
#       <td>-51.279%</td>
#       <td>-25.439%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.27</td>
#       <td>1.27</td>
#       <td>1.16</td>
#       <td>1.40</td>
#       <td>1.34</td>
#       <td>1.32</td>
#       <td>1.08</td>
#       <td>1.65</td>
#       <td>1.29</td>
#       <td>1.28</td>
#       <td>1.18</td>
#       <td>1.40</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>2.03</td>
#       <td>2.01</td>
#       <td>1.22</td>
#       <td>2.89</td>
#       <td>2.19</td>
#       <td>2.13</td>
#       <td>0.44</td>
#       <td>4.23</td>
#       <td>2.00</td>
#       <td>1.98</td>
#       <td>1.21</td>
#       <td>2.82</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.32</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>-1.04</td>
#       <td>-1.07</td>
#       <td>-2.12</td>
#       <td>0.09</td>
#       <td>-0.85</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>2.07</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>9.78</td>
#       <td>9.96</td>
#       <td>4.88</td>
#       <td>14.81</td>
#       <td>11.56</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.02</td>
#       <td>1.02</td>
#       <td>0.95</td>
#       <td>1.11</td>
#       <td>1.06</td>
#       <td>1.07</td>
#       <td>0.86</td>
#       <td>1.26</td>
#       <td>1.07</td>
#       <td>1.07</td>
#       <td>0.97</td>
#       <td>1.15</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.83%</td>
#       <td>-2.832%</td>
#       <td>-2.945%</td>
#       <td>-2.713%</td>
#       <td>-4.471%</td>
#       <td>-4.444%</td>
#       <td>-5.126%</td>
#       <td>-3.89%</td>
#       <td>-3.217%</td>
#       <td>-3.215%</td>
#       <td>-3.412%</td>
#       <td>-3.039%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.19</td>
#       <td>0.19</td>
#       <td>0.08</td>
#       <td>0.30</td>
#       <td>0.81</td>
#       <td>0.75</td>
#       <td>0.19</td>
#       <td>1.62</td>
#       <td>0.23</td>
#       <td>0.22</td>
#       <td>0.11</td>
#       <td>0.36</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>1.10</td>
#       <td>1.10</td>
#       <td>1.03</td>
#       <td>1.17</td>
#       <td>-0.07</td>
#       <td>-0.07</td>
#       <td>-0.18</td>
#       <td>0.04</td>
#       <td>1.05</td>
#       <td>1.05</td>
#       <td>0.94</td>
#       <td>1.16</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>45.35</td>
#       <td>2020-02-20</td>
#       <td>2020-03-18</td>
#       <td>2020-04-29</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>28.34</td>
#       <td>2018-01-26</td>
#       <td>2018-12-24</td>
#       <td>2019-03-21</td>
#       <td>300</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>21.80</td>
#       <td>2020-09-02</td>
#       <td>2020-10-30</td>
#       <td>2020-12-17</td>
#       <td>77</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>21.53</td>
#       <td>2015-03-20</td>
#       <td>2015-09-28</td>
#       <td>2016-04-13</td>
#       <td>279</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>18.32</td>
#       <td>2013-05-21</td>
#       <td>2013-06-24</td>
#       <td>2013-10-25</td>
#       <td>114</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>US downgrade/European Debt Crisis</th>
#       <td>0.32%</td>
#       <td>-5.01%</td>
#       <td>5.74%</td>
#     </tr>
#     <tr>
#       <th>Fukushima</th>
#       <td>0.24%</td>
#       <td>-2.15%</td>
#       <td>2.12%</td>
#     </tr>
#     <tr>
#       <th>EZB IR Event</th>
#       <td>-0.07%</td>
#       <td>-2.03%</td>
#       <td>2.77%</td>
#     </tr>
#     <tr>
#       <th>Flash Crash</th>
#       <td>-0.59%</td>
#       <td>-4.59%</td>
#       <td>3.18%</td>
#     </tr>
#     <tr>
#       <th>Apr14</th>
#       <td>0.21%</td>
#       <td>-2.61%</td>
#       <td>2.01%</td>
#     </tr>
#     <tr>
#       <th>Oct14</th>
#       <td>0.32%</td>
#       <td>-4.15%</td>
#       <td>3.11%</td>
#     </tr>
#     <tr>
#       <th>Fall2015</th>
#       <td>-0.46%</td>
#       <td>-5.70%</td>
#       <td>3.98%</td>
#     </tr>
#     <tr>
#       <th>Recovery</th>
#       <td>0.19%</td>
#       <td>-6.69%</td>
#       <td>7.10%</td>
#     </tr>
#     <tr>
#       <th>New Normal</th>
#       <td>0.13%</td>
#       <td>-17.44%</td>
#       <td>11.98%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 long positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>TMF</th>
#       <td>81.27%</td>
#     </tr>
#     <tr>
#       <th>UPRO</th>
#       <td>80.74%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 short positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>TMF</th>
#       <td>81.27%</td>
#     </tr>
#     <tr>
#       <th>UPRO</th>
#       <td>80.74%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Analytics - Annualized Return and Maximum drawdown

# settings
window = 252
year_length = 252

# copy needed columns
df = result.copy().filter(items=['portfolio_value', 'gross_leverage', 'returns'])

# Annualized Return = (End Value / Start Value) ** (Year Days / Actual Days) - 1
def ann_ret(ts):
    return np.power((ts[-1] / ts[0]), (year_length / len(ts))) - 1

# Maximum drawdown
def dd(ts):
    return np.min(ts / np.maximum.accumulate(ts)) - 1

# rolling window
rolling_window = result.portfolio_value.rolling(window)

# rolling analytics
df['annualized'] = rolling_window.apply(ann_ret)
df['drawdown'] = rolling_window.apply(dd)

# drop initial n/a
df.dropna(inplace = True)

# Figure
fig = plt.figure(figsize = (15, 12))

# Reduce base for easy readability
df['portfolio_value'] /= 100

# First chart
ax = fig.add_subplot(511)
ax.set_title('Strategy Results')
ax.plot(df['portfolio_value'], linestyle = '-', color = 'black', label = 'Equity Curve', linewidth = 3.0)

# log scale
ax.set_yscale('log')

# prettier axis
ax.yaxis.set_ticks(np.arange(df['portfolio_value'].min(), df['portfolio_value'].max(), 500))
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%0.0f'))

# legend and grid
ax.legend()
ax.grid(False)

# Second chart
ax = fig.add_subplot(512)
ax.plot(df['gross_leverage'], 
        linestyle = '-', color = 'black', label = 'Strategy Exposure'.format(window), linewidth = 1.0)

# prettier axis
ax.yaxis.set_ticks(np.arange(df['gross_leverage'].min(), df['gross_leverage'].max(), 0.01 ))
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%0.2f'))

# legend and grid
ax.legend()
ax.grid(True)

# Third chart
ax = fig.add_subplot(513)
ax.plot(df['annualized'], 
        linestyle = '-', color = 'black', label = '{} days annualized return'.format(window), linewidth = 1.0)
ax.axhline(df['annualized'].mean(), color='black', linewidth=1.5, label='Mean {:0.1f}%'.format(df['annualized'].mean() * 100))

# prettier axis
ax.yaxis.set_ticks(np.arange(df['annualized'].min(), df['annualized'].max(), 0.2))
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%0.2f'))

# legend and grid
ax.legend()
ax.grid(True)

# Fourth chart
ax = fig.add_subplot(514)
ax.plot(df['drawdown'], 
        linestyle = '-', color = 'black', label = '{} days max drawdown'.format(window), linewidth = 1.0)

# prettier axis
ax.yaxis.set_ticks(np.arange(df['drawdown'].min(), df['drawdown'].max(), 0.05))
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%0.2f'))

# legend and grid
ax.legend()
ax.grid(True)

# Fifth chart
ax = fig.add_subplot(515)
ax.plot(df['returns'], label = 'Daily Returns', linestyle = '-', linewidth = 1.0)

ax.legend()
ax.grid(True)

# %%
"""
    Monthly Time Return Table
"""


# Used for performance calculations
import empyrical as em

# Used for displaying HTML formatted content in notebook
from IPython.core.display import display, HTML

# Use Empyrical to aggregate on monthly and yearly periods
monthly_data = em.aggregate_returns(result['portfolio_value'].pct_change(), 'monthly')
yearly_data = em.aggregate_returns(result['portfolio_value'].pct_change(), 'yearly')

# Start off an HTML table for display
# HTML Table for display
table = """
<table class='table table-hover table-condensed table-striped'>
<thead>
<tr>
<th style="text-align:right">Year</th>
<th style="text-align:right">Jan</th>
<th style="text-align:right">Feb</th>
<th style="text-align:right">Mar</th>
<th style="text-align:right">Apr</th>
<th style="text-align:right">May</th>
<th style="text-align:right">Jun</th>
<th style="text-align:right">Jul</th>
<th style="text-align:right">Aug</th>
<th style="text-align:right">Sep</th>
<th style="text-align:right">Oct</th>
<th style="text-align:right">Nov</th>
<th style="text-align:right">Dec</th>
<th style="text-align:right">Year</th>
</tr>
</thead>
<tbody>
<tr>"""

# initialize
first_year = True
first_month = True
yr = 0
mnth = 0

# iterate over pandas series
for m, val in monthly_data.iteritems():
    yr = m[0]
    mnth = m[1]
    
    # first month of year, add year label to table
    if (first_month):
        table += "<td align='right'><b>{}</b></td>\n".format(yr)
        first_month = False
    
    # pad empty months for first year if simulation starts later in year
    if (first_year):
        first_year = False
        if (mnth > 1):
            for i in range(1, mnth):
                table += "<td align='right'>-</td>\n"
                
    # add monthly performance
    table += "<td align='right'>{:+.1f}</td>\n".format(val * 100)
    
    # check for 12th month, add annual return number
    if (mnth == 12):
        table += "<td align='right'><b>{:+.1f}</b></td>\n".format(yearly_data[yr] * 100)
        table += '</tr>\n<tr>\n'
        first_month = True
        
# pad empty months for last year
if (mnth != 12):
    for i in range(mnth + 1, 13):
        table +="<td align='right'><b>\n"
        if (i == 12):
            table += "<td align='right'><b>{:+.1f}</b></td>\n".format(yearly_data[yr] * 100)
            table += '</tr>\n<tr>\n'

# finalize table
table += '</tr>\n</tbody>\n</table>'

display(HTML(table))
# Out:
# <table class='table table-hover table-condensed table-striped'>
# <thead>
# <tr>
# <th style="text-align:right">Year</th>
# <th style="text-align:right">Jan</th>
# <th style="text-align:right">Feb</th>
# <th style="text-align:right">Mar</th>
# <th style="text-align:right">Apr</th>
# <th style="text-align:right">May</th>
# <th style="text-align:right">Jun</th>
# <th style="text-align:right">Jul</th>
# <th style="text-align:right">Aug</th>
# <th style="text-align:right">Sep</th>
# <th style="text-align:right">Oct</th>
# <th style="text-align:right">Nov</th>
# <th style="text-align:right">Dec</th>
# <th style="text-align:right">Year</th>
# </tr>
# </thead>
# <tbody>
# <tr><td align='right'><b>2009</b></td>
# <td align='right'>-</td>
# <td align='right'>-</td>
# <td align='right'>-</td>
# <td align='right'>-</td>
# <td align='right'>-</td>
# <td align='right'>+0.0</td>
# <td align='right'>+17.5</td>
# <td align='right'>+8.8</td>
# <td align='right'>+9.0</td>
# <td align='right'>-8.0</td>
# <td align='right'>+13.0</td>
# <td align='right'>-3.2</td>
# <td align='right'><b>+40.2</b></td>
# </tr>
# <tr>
# <td align='right'><b>2010</b></td>
# <td align='right'>-3.1</td>
# <td align='right'>+4.0</td>
# <td align='right'>+7.8</td>
# <td align='right'>+6.8</td>
# <td align='right'>-7.0</td>
# <td align='right'>+1.0</td>
# <td align='right'>+11.3</td>
# <td align='right'>+0.1</td>
# <td align='right'>+12.0</td>
# <td align='right'>+1.3</td>
# <td align='right'>-2.6</td>
# <td align='right'>+10.3</td>
# <td align='right'><b>+47.8</b></td>
# </tr>
# <tr>
# <td align='right'><b>2011</b></td>
# <td align='right'>+0.6</td>
# <td align='right'>+8.2</td>
# <td align='right'>-0.7</td>
# <td align='right'>+7.8</td>
# <td align='right'>+1.7</td>
# <td align='right'>-6.5</td>
# <td align='right'>+1.7</td>
# <td align='right'>+1.1</td>
# <td align='right'>+15.1</td>
# <td align='right'>+20.0</td>
# <td align='right'>-1.2</td>
# <td align='right'>+4.5</td>
# <td align='right'><b>+62.6</b></td>
# </tr>
# <tr>
# <td align='right'><b>2012</b></td>
# <td align='right'>+9.0</td>
# <td align='right'>+5.0</td>
# <td align='right'>+1.7</td>
# <td align='right'>+4.9</td>
# <td align='right'>+3.0</td>
# <td align='right'>+2.0</td>
# <td align='right'>+6.4</td>
# <td align='right'>+1.9</td>
# <td align='right'>+1.6</td>
# <td align='right'>-4.4</td>
# <td align='right'>+2.2</td>
# <td align='right'>-1.6</td>
# <td align='right'><b>+35.9</b></td>
# </tr>
# <tr>
# <td align='right'><b>2013</b></td>
# <td align='right'>+5.3</td>
# <td align='right'>+3.5</td>
# <td align='right'>+6.3</td>
# <td align='right'>+8.8</td>
# <td align='right'>-4.1</td>
# <td align='right'>-7.0</td>
# <td align='right'>+6.9</td>
# <td align='right'>-7.6</td>
# <td align='right'>+6.7</td>
# <td align='right'>+10.0</td>
# <td align='right'>+2.3</td>
# <td align='right'>+2.8</td>
# <td align='right'><b>+37.2</b></td>
# </tr>
# <tr>
# <td align='right'><b>2014</b></td>
# <td align='right'>+0.8</td>
# <td align='right'>+8.1</td>
# <td align='right'>+2.0</td>
# <td align='right'>+3.3</td>
# <td align='right'>+7.5</td>
# <td align='right'>+3.1</td>
# <td align='right'>-1.9</td>
# <td align='right'>+13.0</td>
# <td align='right'>-5.4</td>
# <td align='right'>+7.2</td>
# <td align='right'>+8.6</td>
# <td align='right'>+2.7</td>
# <td align='right'><b>+59.4</b></td>
# </tr>
# <tr>
# <td align='right'><b>2015</b></td>
# <td align='right'>+6.6</td>
# <td align='right'>+0.4</td>
# <td align='right'>-2.2</td>
# <td align='right'>-2.4</td>
# <td align='right'>-0.6</td>
# <td align='right'>-8.3</td>
# <td align='right'>+9.7</td>
# <td align='right'>-11.9</td>
# <td align='right'>-2.1</td>
# <td align='right'>+15.2</td>
# <td align='right'>-0.4</td>
# <td align='right'>-4.9</td>
# <td align='right'><b>-3.8</b></td>
# </tr>
# <tr>
# <td align='right'><b>2016</b></td>
# <td align='right'>-2.9</td>
# <td align='right'>+3.1</td>
# <td align='right'>+10.7</td>
# <td align='right'>-0.5</td>
# <td align='right'>+3.6</td>
# <td align='right'>+8.1</td>
# <td align='right'>+9.6</td>
# <td align='right'>-1.3</td>
# <td align='right'>-2.1</td>
# <td align='right'>-8.6</td>
# <td align='right'>-2.2</td>
# <td align='right'>+3.9</td>
# <td align='right'><b>+21.3</b></td>
# </tr>
# <tr>
# <td align='right'><b>2017</b></td>
# <td align='right'>+3.9</td>
# <td align='right'>+9.0</td>
# <td align='right'>-1.0</td>
# <td align='right'>+3.4</td>
# <td align='right'>+4.3</td>
# <td align='right'>+1.7</td>
# <td align='right'>+2.5</td>
# <td align='right'>+4.0</td>
# <td align='right'>+0.4</td>
# <td align='right'>+3.9</td>
# <td align='right'>+6.1</td>
# <td align='right'>+4.0</td>
# <td align='right'><b>+50.9</b></td>
# </tr>
# <tr>
# <td align='right'><b>2018</b></td>
# <td align='right'>+6.9</td>
# <td align='right'>-12.2</td>
# <td align='right'>-2.5</td>
# <td align='right'>-2.6</td>
# <td align='right'>+6.0</td>
# <td align='right'>+1.4</td>
# <td align='right'>+4.5</td>
# <td align='right'>+7.0</td>
# <td align='right'>-2.3</td>
# <td align='right'>-16.0</td>
# <td align='right'>+4.5</td>
# <td align='right'>-6.7</td>
# <td align='right'><b>-14.3</b></td>
# </tr>
# <tr>
# <td align='right'><b>2019</b></td>
# <td align='right'>+16.6</td>
# <td align='right'>+4.4</td>
# <td align='right'>+8.6</td>
# <td align='right'>+4.7</td>
# <td align='right'>-3.8</td>
# <td align='right'>+12.2</td>
# <td align='right'>+2.3</td>
# <td align='right'>+10.0</td>
# <td align='right'>-1.7</td>
# <td align='right'>+2.6</td>
# <td align='right'>+6.0</td>
# <td align='right'>+2.1</td>
# <td align='right'><b>+83.5</b></td>
# </tr>
# <tr>
# <td align='right'><b>2020</b></td>
# <td align='right'>+8.1</td>
# <td align='right'>-4.5</td>
# <td align='right'>-14.7</td>
# <td align='right'>+31.7</td>
# <td align='right'>+7.7</td>
# <td align='right'>+2.6</td>
# <td align='right'>+16.5</td>
# <td align='right'>+7.4</td>
# <td align='right'>-7.7</td>
# <td align='right'>-9.3</td>
# <td align='right'>+22.9</td>
# <td align='right'>+6.7</td>
# <td align='right'><b>+76.0</b></td>
# </tr>
# <tr>
# <td align='right'><b>2021</b></td>
# <td align='right'>-6.5</td>
# <td align='right'>-1.4</td>
# <td align='right'>+4.3</td>
# <td align='right'>+12.9</td>
# <td align='right'>+0.7</td>
# <td align='right'>+2.4</td>
# <td align='right'><b>
# <td align='right'><b>
# <td align='right'><b>
# <td align='right'><b>
# <td align='right'><b>
# <td align='right'><b>
# <td align='right'><b>+11.9</b></td>
# </tr>
# <tr>
# </tr>
# </tbody>
# </table>

# %%
"""
    Holding period table

    Shows percentage return if you started in January of a given year and held for certain number of full years.
    In Table you can see what would have happened if you strated this strategy at a given year, and kept trading it
    for number of years from that point. This can be a useful way to quickly get an overview of how the initial
    starting time sometimes can matter quite a lot for a trading model. The numbers show annualized return over
    the number of years displayed on the x-axis.
"""


def holding_period_map(df):
    
    # agreegate yearly data
    yr = em.aggregate_returns(result['portfolio_value'].pct_change(), 'yearly')
    df = pd.DataFrame(columns=range(1,len(yr)+1), index=yr.index)

    yr_start = 0
    
    # start table
    table = "<table class='table table-hover table-condensed table-striped'>"
    table += "<tr><th>Years</th>"
    
    # build first row
    for i in range(len(yr)):
        table += "<th>{}</th>".format(i+1)
    table += "</tr>"

    # iterate years
    for the_year, value in yr.iteritems():
        # new table row
        table += "<tr><th>{}</th>".format(the_year)
        
        # iterate years held
        for yrs_held in (range(1, len(yr)+1)):
            if yrs_held   <= len(yr[yr_start:yr_start + yrs_held]):
                ret = em.annual_return(yr[yr_start:yr_start + yrs_held], 'yearly' )
                table += "<td>{:+.1f}</td>".format(ret * 100)
        table += "</tr>"    
        yr_start+=1
    return table

table = holding_period_map(df)
display(HTML(table))
# Out:
# <table class='table table-hover table-condensed table-striped'><tr><th>Years</th><th>1</th><th>2</th><th>3</th><th>4</th><th>5</th><th>6</th><th>7</th><th>8</th><th>9</th><th>10</th><th>11</th><th>12</th><th>13</th></tr><tr><th>2009</th><td>+40.2</td><td>+43.9</td><td>+49.9</td><td>+46.3</td><td>+44.4</td><td>+46.8</td><td>+38.2</td><td>+36.0</td><td>+37.6</td><td>+31.2</td><td>+35.3</td><td>+38.3</td><td>+36.0</td></tr><tr><th>2010</th><td>+47.8</td><td>+55.0</td><td>+48.4</td><td>+45.5</td><td>+48.2</td><td>+37.9</td><td>+35.4</td><td>+37.2</td><td>+30.2</td><td>+34.8</td><td>+38.1</td><td>+35.7</td></tr><tr><th>2011</th><td>+62.6</td><td>+48.7</td><td>+44.7</td><td>+48.3</td><td>+36.0</td><td>+33.4</td><td>+35.8</td><td>+28.2</td><td>+33.4</td><td>+37.2</td><td>+34.6</td></tr><tr><th>2012</th><td>+35.9</td><td>+36.5</td><td>+43.8</td><td>+30.1</td><td>+28.3</td><td>+31.8</td><td>+23.9</td><td>+30.2</td><td>+34.6</td><td>+32.1</td></tr><tr><th>2013</th><td>+37.2</td><td>+47.9</td><td>+28.2</td><td>+26.4</td><td>+31.0</td><td>+22.0</td><td>+29.3</td><td>+34.4</td><td>+31.7</td></tr><tr><th>2014</th><td>+59.4</td><td>+23.9</td><td>+23.0</td><td>+29.4</td><td>+19.2</td><td>+28.1</td><td>+34.0</td><td>+31.0</td></tr><tr><th>2015</th><td>-3.8</td><td>+8.0</td><td>+20.8</td><td>+10.8</td><td>+22.6</td><td>+30.2</td><td>+27.4</td></tr><tr><th>2016</th><td>+21.3</td><td>+35.3</td><td>+16.2</td><td>+30.2</td><td>+38.3</td><td>+33.5</td></tr><tr><th>2017</th><td>+50.9</td><td>+13.7</td><td>+33.4</td><td>+42.9</td><td>+36.1</td></tr><tr><th>2018</th><td>-14.3</td><td>+25.4</td><td>+40.4</td><td>+32.7</td></tr><tr><th>2019</th><td>+83.5</td><td>+79.7</td><td>+53.5</td></tr><tr><th>2020</th><td>+76.0</td><td>+40.4</td></tr><tr><th>2021</th><td>+11.9</td></tr>

# %%
# Create Round Trip Tear Sheet
# It generates ValueError: Axis limits cannot be NaN or Inf, that stops processing of rest of the code

pf.create_round_trip_tear_sheet(
    returns, 
    positions, 
    transactions,
    return_fig = True
)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Summary stats</th>
#       <th>All trades</th>
#       <th>Long trades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Total number of round_trips</th>
#       <td>49.00</td>
#       <td>49.00</td>
#     </tr>
#     <tr>
#       <th>Percent profitable</th>
#       <td>0.98</td>
#       <td>0.98</td>
#     </tr>
#     <tr>
#       <th>Winning round_trips</th>
#       <td>48.00</td>
#       <td>48.00</td>
#     </tr>
#     <tr>
#       <th>Losing round_trips</th>
#       <td>1.00</td>
#       <td>1.00</td>
#     </tr>
#     <tr>
#       <th>Even round_trips</th>
#       <td>0.00</td>
#       <td>0.00</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>PnL stats</th>
#       <th>All trades</th>
#       <th>Long trades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Total profit</th>
#       <td>$536277.38</td>
#       <td>$536277.38</td>
#     </tr>
#     <tr>
#       <th>Gross profit</th>
#       <td>$568488.35</td>
#       <td>$568488.35</td>
#     </tr>
#     <tr>
#       <th>Gross loss</th>
#       <td>$-32210.97</td>
#       <td>$-32210.97</td>
#     </tr>
#     <tr>
#       <th>Profit factor</th>
#       <td>$17.65</td>
#       <td>$17.65</td>
#     </tr>
#     <tr>
#       <th>Avg. trade net profit</th>
#       <td>$10944.44</td>
#       <td>$10944.44</td>
#     </tr>
#     <tr>
#       <th>Avg. winning trade</th>
#       <td>$11843.51</td>
#       <td>$11843.51</td>
#     </tr>
#     <tr>
#       <th>Avg. losing trade</th>
#       <td>$-32210.97</td>
#       <td>$-32210.97</td>
#     </tr>
#     <tr>
#       <th>Ratio Avg. Win:Avg. Loss</th>
#       <td>$0.37</td>
#       <td>$0.37</td>
#     </tr>
#     <tr>
#       <th>Largest winning trade</th>
#       <td>$258235.06</td>
#       <td>$258235.06</td>
#     </tr>
#     <tr>
#       <th>Largest losing trade</th>
#       <td>$-32210.97</td>
#       <td>$-32210.97</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Duration stats</th>
#       <th>All trades</th>
#       <th>Long trades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avg duration</th>
#       <td>1204 days 15:58:46.571428544</td>
#       <td>1204 days 15:58:46.571428544</td>
#     </tr>
#     <tr>
#       <th>Median duration</th>
#       <td>1097 days 00:00:00</td>
#       <td>1097 days 00:00:00</td>
#     </tr>
#     <tr>
#       <th>Longest duration</th>
#       <td>2740 days 04:00:00</td>
#       <td>2740 days 04:00:00</td>
#     </tr>
#     <tr>
#       <th>Shortest duration</th>
#       <td>92 days 00:00:00</td>
#       <td>92 days 00:00:00</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Return stats</th>
#       <th>All trades</th>
#       <th>Long trades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avg returns all round_trips</th>
#       <td>5.20%</td>
#       <td>5.20%</td>
#     </tr>
#     <tr>
#       <th>Avg returns winning</th>
#       <td>5.44%</td>
#       <td>5.44%</td>
#     </tr>
#     <tr>
#       <th>Avg returns losing</th>
#       <td>-6.08%</td>
#       <td>-6.08%</td>
#     </tr>
#     <tr>
#       <th>Median returns all round_trips</th>
#       <td>3.22%</td>
#       <td>3.22%</td>
#     </tr>
#     <tr>
#       <th>Median returns winning</th>
#       <td>3.23%</td>
#       <td>3.23%</td>
#     </tr>
#     <tr>
#       <th>Median returns losing</th>
#       <td>-6.08%</td>
#       <td>-6.08%</td>
#     </tr>
#     <tr>
#       <th>Largest winning trade</th>
#       <td>48.71%</td>
#       <td>48.71%</td>
#     </tr>
#     <tr>
#       <th>Largest losing trade</th>
#       <td>-6.08%</td>
#       <td>-6.08%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Symbol stats</th>
#       <th>TMF</th>
#       <th>UPRO</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avg returns all round_trips</th>
#       <td>4.87%</td>
#       <td>5.39%</td>
#     </tr>
#     <tr>
#       <th>Avg returns winning</th>
#       <td>4.87%</td>
#       <td>5.75%</td>
#     </tr>
#     <tr>
#       <th>Avg returns losing</th>
#       <td>NaN</td>
#       <td>-6.08%</td>
#     </tr>
#     <tr>
#       <th>Median returns all round_trips</th>
#       <td>3.72%</td>
#       <td>3.03%</td>
#     </tr>
#     <tr>
#       <th>Median returns winning</th>
#       <td>3.72%</td>
#       <td>3.12%</td>
#     </tr>
#     <tr>
#       <th>Median returns losing</th>
#       <td>NaN</td>
#       <td>-6.08%</td>
#     </tr>
#     <tr>
#       <th>Largest winning trade</th>
#       <td>18.71%</td>
#       <td>48.71%</td>
#     </tr>
#     <tr>
#       <th>Largest losing trade</th>
#       <td>0.02%</td>
#       <td>-6.08%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Profitability (PnL / PnL total) per name</th>
#       <th></th>
#     </tr>
#     <tr>
#       <th>symbol</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>UPRO</th>
#       <td>89.44%</td>
#     </tr>
#     <tr>
#       <th>TMF</th>
#       <td>10.56%</td>
#     </tr>
#   </tbody>
# </table>

# %%
pf.plotting.plot_monthly_returns_heatmap(returns)
# Out:
# <AxesSubplot:title={'center':'Monthly returns (%)'}, xlabel='Month', ylabel='Year'>

# %%
pf.plotting.plot_monthly_returns_dist(returns)
# Out:
# <AxesSubplot:title={'center':'Distribution of monthly returns'}, xlabel='Returns', ylabel='Number of months'>
