# %%
"""
    Asset Allocation Model
    Two Leveraged ETFs with target weight
    Leverage ETFs: TQQQ, TMF
    Rebalancing: Yearly
"""
# %matplotlib inline

# silence warnings
import warnings
warnings.filterwarnings('ignore')

import zipline
from zipline.api import order_target_percent, symbol, schedule_function, date_rules, time_rules, set_benchmark, get_datetime
from datetime import datetime
import pytz
import pyfolio as pf
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt, ticker, rc
from scipy import stats

# %%
# Sector Map for ETFs
sect_map = {'TMF': 'Long term Treasuries', 'UPRO':'S&P500', 'TQQQ':'Nasdaq'}

# Rebalance in January
YEAR_START = [1]

def initialize(context):
    # ETFs and target weight
    context.securities = {
        'TQQQ': 0.60,
        'TMF': 0.40
    }
    
    set_benchmark(symbol('SPY'))
    
    # setting a flag for first time purchase at portfolio initiation
    context.has_ordered = False
    
    # schedule rebalance once a month
    schedule_function(rebalance, date_rules.month_start(), time_rules.market_open())

# %%
def rebalance(context, data):
    
    # Annual Rebalcing First of January
    # If the current month number is not in YEAR_START,
    # don't do anything.
    month_number = get_datetime().date().month
    if context.has_ordered and month_number not in YEAR_START:
        return

    # Otherwise, execute rebalance
    # Loop thru ETFs
    for sec, weight in context.securities.items():
        sym = symbol(sec)
        # check if can trade
        if data.can_trade(sym):
            # Reset weight
            order_target_percent(sym, weight)
            
    # Set flag after the first order since portfolio creation
    context.has_ordered = True

# %%
def month_perf(ts):
    perf = (ts[-1] / ts[0]) - 1
    return perf

# %%
def analyze(context, perf):
    # Extract algo returns and benchmark returns
    returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(perf)
    benchmark_period_return = perf['benchmark_period_return']
    
    # Convert benchmark returns to daily returns
    #daily_returns = (1 + benchmark_period_return) / (1 + benchmark_period_return.shift()) - 1
    daily_benchmark_returns = np.exp(np.log(benchmark_period_return + 1.0).diff()) - 1

    # Create tear sheet
    # Note: Live start date is Bogleheads forum HEDGEFUNDIE's post start date https://www.bogleheads.org/forum/viewtopic.php?f=10&t=272007
    pf.create_full_tear_sheet(live_start_date='2019-02-05', returns = returns, positions = positions, transactions = transactions, round_trips = False, benchmark_rets=daily_benchmark_returns)
    # Note: The round trip tear sheet is done separately at the bottom. The error interferes with execution of the rest of the program

# %%
# Set start and end
start = pd.to_datetime('2010-02-11', utc=True)
end = pd.to_datetime('2021-06-04', utc=True)

# Fire off backtest
result = zipline.run_algorithm(
    start = start, 
    end = end, 
    initialize = initialize,
    analyze = analyze,
    capital_base = 10000, 
    data_frequency = 'daily', 
    bundle = 'etf_db_data'
)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=4>2010-02-11</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=4>2021-06-04</td></tr>
#     <tr style="text-align: right;"><th>In-sample months</th><td colspan=4>107</td></tr>
#     <tr style="text-align: right;"><th>Out-of-sample months</th><td colspan=4>28</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>In-sample</th>
#       <th>Out-of-sample</th>
#       <th>All</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>34.403%</td>
#       <td>58.176%</td>
#       <td>38.999%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>1317.767%</td>
#       <td>191.517%</td>
#       <td>4033.035%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>28.757%</td>
#       <td>42.449%</td>
#       <td>32.063%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.17</td>
#       <td>1.30</td>
#       <td>1.19</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.84</td>
#       <td>1.29</td>
#       <td>0.86</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.97</td>
#       <td>0.93</td>
#       <td>0.98</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-40.792%</td>
#       <td>-45.122%</td>
#       <td>-45.122%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.22</td>
#       <td>1.26</td>
#       <td>1.23</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.67</td>
#       <td>1.80</td>
#       <td>1.68</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.39</td>
#       <td>-0.73</td>
#       <td>-0.55</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>2.04</td>
#       <td>3.93</td>
#       <td>3.94</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.94</td>
#       <td>0.95</td>
#       <td>0.99</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-3.489%</td>
#       <td>-5.13%</td>
#       <td>-3.888%</td>
#     </tr>
#     <tr>
#       <th>Gross leverage</th>
#       <td>1.00</td>
#       <td>1.00</td>
#       <td>1.00</td>
#     </tr>
#     <tr>
#       <th>Daily turnover</th>
#       <td>0.176%</td>
#       <td>0.07%</td>
#       <td>0.154%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.19</td>
#       <td>0.38</td>
#       <td>0.23</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>1.22</td>
#       <td>0.97</td>
#       <td>1.12</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>45.12</td>
#       <td>2020-02-19</td>
#       <td>2020-03-18</td>
#       <td>2020-07-01</td>
#       <td>96</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>40.79</td>
#       <td>2018-08-29</td>
#       <td>2018-12-24</td>
#       <td>2019-05-03</td>
#       <td>178</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>26.69</td>
#       <td>2021-02-12</td>
#       <td>2021-03-08</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>26.30</td>
#       <td>2020-09-02</td>
#       <td>2020-10-30</td>
#       <td>2021-01-21</td>
#       <td>102</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>24.30</td>
#       <td>2015-04-24</td>
#       <td>2015-08-25</td>
#       <td>2016-06-30</td>
#       <td>310</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>US downgrade/European Debt Crisis</th>
#       <td>0.28%</td>
#       <td>-5.46%</td>
#       <td>6.28%</td>
#     </tr>
#     <tr>
#       <th>Fukushima</th>
#       <td>0.16%</td>
#       <td>-3.13%</td>
#       <td>2.53%</td>
#     </tr>
#     <tr>
#       <th>EZB IR Event</th>
#       <td>-0.35%</td>
#       <td>-3.82%</td>
#       <td>2.45%</td>
#     </tr>
#     <tr>
#       <th>Flash Crash</th>
#       <td>-0.79%</td>
#       <td>-6.21%</td>
#       <td>5.52%</td>
#     </tr>
#     <tr>
#       <th>Apr14</th>
#       <td>0.17%</td>
#       <td>-3.92%</td>
#       <td>2.27%</td>
#     </tr>
#     <tr>
#       <th>Oct14</th>
#       <td>0.32%</td>
#       <td>-3.36%</td>
#       <td>3.19%</td>
#     </tr>
#     <tr>
#       <th>Fall2015</th>
#       <td>-0.52%</td>
#       <td>-7.48%</td>
#       <td>5.75%</td>
#     </tr>
#     <tr>
#       <th>Recovery</th>
#       <td>0.14%</td>
#       <td>-6.21%</td>
#       <td>6.76%</td>
#     </tr>
#     <tr>
#       <th>New Normal</th>
#       <td>0.15%</td>
#       <td>-15.19%</td>
#       <td>10.60%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 long positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>TQQQ</th>
#       <td>83.70%</td>
#     </tr>
#     <tr>
#       <th>TMF</th>
#       <td>74.05%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 short positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>TQQQ</th>
#       <td>83.70%</td>
#     </tr>
#     <tr>
#       <th>TMF</th>
#       <td>74.05%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Analytics - Annualized Return and Maximum drawdown

# Settings
window = 252
year_length = 252

# Copy the columns we need
df = result.copy().filter(items=['portfolio_value', 'gross_leverage', 'returns'])

# Function for annualized return
def ann_ret(ts):
    return np.power((ts[-1] / ts[0]), (year_length/len(ts))) -1  

# Function for drawdown
def dd(ts):
    return np.min(ts / np.maximum.accumulate(ts)) - 1

# Get a rolling window
rolling_window = result.portfolio_value.rolling(window)

# Calculate rolling analytics
df['annualized'] = rolling_window.apply(ann_ret)
df['drawdown'] = rolling_window.apply(dd)

# Drop initial n/a values
df.dropna(inplace=True)

# Make a figure
fig = plt.figure(figsize=(15, 12))

# Make the base lower, just to make the graph easier to read
df['portfolio_value'] /= 100

# First chart
ax = fig.add_subplot(511)
ax.set_title('Strategy Results')
ax.plot(df['portfolio_value'], 
        linestyle='-', 
        color='black',
        label='Equity Curve', linewidth=3.0)

# Set log scale
ax.set_yscale('log') 

# Make the axis look nicer
ax.yaxis.set_ticks(np.arange(df['portfolio_value'].min(), df['portfolio_value'].max(), 500 ))
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%0.0f'))

# Add legend and grid
ax.legend()
ax.grid(False)

# Second chart
ax = fig.add_subplot(512)
ax.plot(df['gross_leverage'], 
        label='Strategy exposure'.format(window), 
        linestyle='-', 
        color='black',
        linewidth=1.0)

# Make the axis look nicer
ax.yaxis.set_ticks(np.arange(df['gross_leverage'].min(), df['gross_leverage'].max(), 0.01 ))
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%0.2f'))

# Add legend and grid
ax.legend()
ax.grid(True)

# Third chart
ax = fig.add_subplot(513)
ax.plot(df['annualized'], 
        label='{} days annualized return'.format(window), 
        linestyle='-', 
        color='black',
        linewidth=1.0)
ax.axhline(df['annualized'].mean(), color='black', linewidth=1.5, 
           label='Mean {:0.1f}%'.format(df['annualized'].mean() * 100))

# Make the axis look nicer
ax.yaxis.set_ticks(np.arange(df['annualized'].min(), df['annualized'].max(), 0.2 ))
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%0.2f'))

# Add legend and grid
ax.legend()
ax.grid(True)

# Fourth chart
ax = fig.add_subplot(514)
ax.plot(df['drawdown'], 
        label='{} days max drawdown'.format(window), 
        linestyle='-', 
        color='black',
        linewidth=1.0)

# Make the axis look nicer
ax.yaxis.set_ticks(np.arange(df['drawdown'].min(), df['drawdown'].max(), 0.05 ))
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%0.2f'))

# Add legend and grid
ax.legend()
ax.grid(True)

# Fifth chart
ax = fig.add_subplot(515)
ax.plot(df['returns'], label = 'Daily Returns', linestyle='-.', linewidth = 1.0)
ax.legend()
ax.grid(True)

# %%
"""
    Monthly Time Return Table
"""


# Used for performance calculations
import empyrical as em

# Used for displaying HTML formatted content in notebook
from IPython.core.display import display, HTML

# Use Empyrical to aggregate on monthly and yearly periods
monthly_data = em.aggregate_returns(result['portfolio_value'].pct_change(), 'monthly')
yearly_data = em.aggregate_returns(result['portfolio_value'].pct_change(), 'yearly')

# Start off an HTML table for display
# HTML Table for display
table = """
<table class='table table-hover table-condensed table-striped'>
<thead>
<tr>
<th style="text-align:right">Year</th>
<th style="text-align:right">Jan</th>
<th style="text-align:right">Feb</th>
<th style="text-align:right">Mar</th>
<th style="text-align:right">Apr</th>
<th style="text-align:right">May</th>
<th style="text-align:right">Jun</th>
<th style="text-align:right">Jul</th>
<th style="text-align:right">Aug</th>
<th style="text-align:right">Sep</th>
<th style="text-align:right">Oct</th>
<th style="text-align:right">Nov</th>
<th style="text-align:right">Dec</th>
<th style="text-align:right">Year</th>
</tr>
</thead>
<tbody>
<tr>"""

# initialize
first_year = True
first_month = True
yr = 0
mnth = 0

# iterate over pandas series
for m, val in monthly_data.iteritems():
    yr = m[0]
    mnth = m[1]
    
    # first month of year, add year label to table
    if (first_month):
        table += "<td align='right'><b>{}</b></td>\n".format(yr)
        first_month = False
    
    # pad empty months for first year if simulation starts later in year
    if (first_year):
        first_year = False
        if (mnth > 1):
            for i in range(1, mnth):
                table += "<td align='right'>-</td>\n"
                
    # add monthly performance
    table += "<td align='right'>{:+.1f}</td>\n".format(val * 100)
    
    # check for 12th month, add annual return number
    if (mnth == 12):
        table += "<td align='right'><b>{:+.1f}</b></td>\n".format(yearly_data[yr] * 100)
        table += '</tr>\n<tr>\n'
        first_month = True
        
# pad empty months for last year
if (mnth != 12):
    for i in range(mnth + 1, 13):
        table +="<td align='right'><b>\n"
        if (i == 12):
            table += "<td align='right'><b>{:+.1f}</b></td>\n".format(yearly_data[yr] * 100)
            table += '</tr>\n<tr>\n'

# finalize table
table += '</tr>\n</tbody>\n</table>'

display(HTML(table))
# Out:
# <table class='table table-hover table-condensed table-striped'>
# <thead>
# <tr>
# <th style="text-align:right">Year</th>
# <th style="text-align:right">Jan</th>
# <th style="text-align:right">Feb</th>
# <th style="text-align:right">Mar</th>
# <th style="text-align:right">Apr</th>
# <th style="text-align:right">May</th>
# <th style="text-align:right">Jun</th>
# <th style="text-align:right">Jul</th>
# <th style="text-align:right">Aug</th>
# <th style="text-align:right">Sep</th>
# <th style="text-align:right">Oct</th>
# <th style="text-align:right">Nov</th>
# <th style="text-align:right">Dec</th>
# <th style="text-align:right">Year</th>
# </tr>
# </thead>
# <tbody>
# <tr><td align='right'><b>2010</b></td>
# <td align='right'>-</td>
# <td align='right'>+0.0</td>
# <td align='right'>+8.7</td>
# <td align='right'>+7.4</td>
# <td align='right'>-9.1</td>
# <td align='right'>-2.9</td>
# <td align='right'>+8.0</td>
# <td align='right'>+4.6</td>
# <td align='right'>+13.0</td>
# <td align='right'>+4.1</td>
# <td align='right'>-3.2</td>
# <td align='right'>+4.9</td>
# <td align='right'><b>+39.1</b></td>
# </tr>
# <tr>
# <td align='right'><b>2011</b></td>
# <td align='right'>+1.4</td>
# <td align='right'>+7.4</td>
# <td align='right'>-1.7</td>
# <td align='right'>+7.8</td>
# <td align='right'>+1.0</td>
# <td align='right'>-7.2</td>
# <td align='right'>+7.9</td>
# <td align='right'>-0.1</td>
# <td align='right'>+15.1</td>
# <td align='right'>+2.7</td>
# <td align='right'>-1.9</td>
# <td align='right'>+4.4</td>
# <td align='right'><b>+41.4</b></td>
# </tr>
# <tr>
# <td align='right'><b>2012</b></td>
# <td align='right'>+11.7</td>
# <td align='right'>+10.0</td>
# <td align='right'>+6.8</td>
# <td align='right'>+0.3</td>
# <td align='right'>-6.5</td>
# <td align='right'>+3.7</td>
# <td align='right'>+5.6</td>
# <td align='right'>+8.4</td>
# <td align='right'>-1.2</td>
# <td align='right'>-11.6</td>
# <td align='right'>+3.5</td>
# <td align='right'>-4.0</td>
# <td align='right'><b>+27.0</b></td>
# </tr>
# <tr>
# <td align='right'><b>2013</b></td>
# <td align='right'>+1.8</td>
# <td align='right'>+1.7</td>
# <td align='right'>+4.6</td>
# <td align='right'>+9.6</td>
# <td align='right'>-1.0</td>
# <td align='right'>-8.7</td>
# <td align='right'>+11.6</td>
# <td align='right'>-2.4</td>
# <td align='right'>+11.5</td>
# <td align='right'>+12.3</td>
# <td align='right'>+6.4</td>
# <td align='right'>+6.1</td>
# <td align='right'><b>+65.1</b></td>
# </tr>
# <tr>
# <td align='right'><b>2014</b></td>
# <td align='right'>+2.4</td>
# <td align='right'>+9.2</td>
# <td align='right'>-4.1</td>
# <td align='right'>+1.5</td>
# <td align='right'>+11.4</td>
# <td align='right'>+4.7</td>
# <td align='right'>+2.4</td>
# <td align='right'>+15.1</td>
# <td align='right'>-4.4</td>
# <td align='right'>+7.2</td>
# <td align='right'>+12.2</td>
# <td align='right'>-0.6</td>
# <td align='right'><b>+71.0</b></td>
# </tr>
# <tr>
# <td align='right'><b>2015</b></td>
# <td align='right'>+8.7</td>
# <td align='right'>+3.5</td>
# <td align='right'>-3.7</td>
# <td align='right'>-1.0</td>
# <td align='right'>+1.2</td>
# <td align='right'>-9.2</td>
# <td align='right'>+13.3</td>
# <td align='right'>-15.3</td>
# <td align='right'>-3.3</td>
# <td align='right'>+21.6</td>
# <td align='right'>+0.0</td>
# <td align='right'>-4.7</td>
# <td align='right'><b>+5.9</b></td>
# </tr>
# <tr>
# <td align='right'><b>2016</b></td>
# <td align='right'>-6.9</td>
# <td align='right'>+1.0</td>
# <td align='right'>+9.9</td>
# <td align='right'>-6.2</td>
# <td align='right'>+7.5</td>
# <td align='right'>+5.4</td>
# <td align='right'>+13.9</td>
# <td align='right'>-0.2</td>
# <td align='right'>+0.8</td>
# <td align='right'>-8.5</td>
# <td align='right'>-9.5</td>
# <td align='right'>+1.3</td>
# <td align='right'><b>+5.6</b></td>
# </tr>
# <tr>
# <td align='right'><b>2017</b></td>
# <td align='right'>+10.1</td>
# <td align='right'>+10.0</td>
# <td align='right'>+2.8</td>
# <td align='right'>+6.9</td>
# <td align='right'>+9.4</td>
# <td align='right'>-4.9</td>
# <td align='right'>+7.5</td>
# <td align='right'>+6.6</td>
# <td align='right'>-3.0</td>
# <td align='right'>+9.4</td>
# <td align='right'>+4.5</td>
# <td align='right'>+2.2</td>
# <td align='right'><b>+79.8</b></td>
# </tr>
# <tr>
# <td align='right'><b>2018</b></td>
# <td align='right'>+13.5</td>
# <td align='right'>-7.3</td>
# <td align='right'>-6.2</td>
# <td align='right'>-2.8</td>
# <td align='right'>+12.7</td>
# <td align='right'>+1.9</td>
# <td align='right'>+3.4</td>
# <td align='right'>+13.2</td>
# <td align='right'>-3.7</td>
# <td align='right'>-21.8</td>
# <td align='right'>-0.5</td>
# <td align='right'>-11.9</td>
# <td align='right'><b>-14.9</b></td>
# </tr>
# <tr>
# <td align='right'><b>2019</b></td>
# <td align='right'>+16.9</td>
# <td align='right'>+4.0</td>
# <td align='right'>+12.9</td>
# <td align='right'>+9.0</td>
# <td align='right'>-11.3</td>
# <td align='right'>+14.8</td>
# <td align='right'>+4.2</td>
# <td align='right'>+6.2</td>
# <td align='right'>-2.7</td>
# <td align='right'>+6.0</td>
# <td align='right'>+7.2</td>
# <td align='right'>+4.5</td>
# <td align='right'><b>+94.9</b></td>
# </tr>
# <tr>
# <td align='right'><b>2020</b></td>
# <td align='right'>+13.7</td>
# <td align='right'>-2.2</td>
# <td align='right'>-11.9</td>
# <td align='right'>+17.4</td>
# <td align='right'>+4.0</td>
# <td align='right'>+8.9</td>
# <td align='right'>+18.0</td>
# <td align='right'>+11.9</td>
# <td align='right'>-11.5</td>
# <td align='right'>-10.4</td>
# <td align='right'>+22.3</td>
# <td align='right'>+9.1</td>
# <td align='right'><b>+81.9</b></td>
# </tr>
# <tr>
# <td align='right'><b>2021</b></td>
# <td align='right'>-4.5</td>
# <td align='right'>-7.0</td>
# <td align='right'>-3.5</td>
# <td align='right'>+14.6</td>
# <td align='right'>-3.5</td>
# <td align='right'>+2.0</td>
# <td align='right'><b>
# <td align='right'><b>
# <td align='right'><b>
# <td align='right'><b>
# <td align='right'><b>
# <td align='right'><b>
# <td align='right'><b>-3.3</b></td>
# </tr>
# <tr>
# </tr>
# </tbody>
# </table>

# %%
"""
    Holding period table

    Shows percentage return if you started in January of a given year and held for certain number of full years.
    In Table you can see what would have happened if you strated this strategy at a given year, and kept trading it
    for number of years from that point. This can be a useful way to quickly get an overview of how the initial
    starting time sometimes can matter quite a lot for a trading model. The numbers show annualized return over
    the number of years displayed on the x-axis.
"""


def holding_period_map(df):
    
    # agreegate yearly data
    yr = em.aggregate_returns(result['portfolio_value'].pct_change(), 'yearly')
    df = pd.DataFrame(columns=range(1,len(yr)+1), index=yr.index)

    yr_start = 0
    
    # start table
    table = "<table class='table table-hover table-condensed table-striped'>"
    table += "<tr><th>Years</th>"
    
    # build first row
    for i in range(len(yr)):
        table += "<th>{}</th>".format(i+1)
    table += "</tr>"

    # iterate years
    for the_year, value in yr.iteritems():
        # new table row
        table += "<tr><th>{}</th>".format(the_year)
        
        # iterate years held
        for yrs_held in (range(1, len(yr)+1)):
            if yrs_held   <= len(yr[yr_start:yr_start + yrs_held]):
                ret = em.annual_return(yr[yr_start:yr_start + yrs_held], 'yearly' )
                table += "<td>{:+.1f}</td>".format(ret * 100)
        table += "</tr>"    
        yr_start+=1
    return table

table = holding_period_map(df)
display(HTML(table))
# Out:
# <table class='table table-hover table-condensed table-striped'><tr><th>Years</th><th>1</th><th>2</th><th>3</th><th>4</th><th>5</th><th>6</th><th>7</th><th>8</th><th>9</th><th>10</th><th>11</th><th>12</th></tr><tr><th>2010</th><td>+39.1</td><td>+40.2</td><td>+35.7</td><td>+42.5</td><td>+47.8</td><td>+39.8</td><td>+34.3</td><td>+39.3</td><td>+31.9</td><td>+37.1</td><td>+40.7</td><td>+36.4</td></tr><tr><th>2011</th><td>+41.4</td><td>+34.0</td><td>+43.6</td><td>+50.0</td><td>+39.9</td><td>+33.5</td><td>+39.3</td><td>+31.0</td><td>+36.9</td><td>+40.9</td><td>+36.1</td></tr><tr><th>2012</th><td>+27.0</td><td>+44.8</td><td>+53.0</td><td>+39.6</td><td>+32.0</td><td>+39.0</td><td>+29.6</td><td>+36.4</td><td>+40.8</td><td>+35.6</td></tr><tr><th>2013</th><td>+65.1</td><td>+68.0</td><td>+44.1</td><td>+33.3</td><td>+41.5</td><td>+30.0</td><td>+37.8</td><td>+42.6</td><td>+36.6</td></tr><tr><th>2014</th><td>+71.0</td><td>+34.6</td><td>+24.1</td><td>+36.2</td><td>+24.0</td><td>+33.7</td><td>+39.7</td><td>+33.4</td></tr><tr><th>2015</th><td>+5.9</td><td>+5.7</td><td>+26.2</td><td>+14.4</td><td>+27.2</td><td>+35.0</td><td>+28.7</td></tr><tr><th>2016</th><td>+5.6</td><td>+37.8</td><td>+17.4</td><td>+33.2</td><td>+41.8</td><td>+33.0</td></tr><tr><th>2017</th><td>+79.8</td><td>+23.7</td><td>+43.9</td><td>+52.6</td><td>+39.3</td></tr><tr><th>2018</th><td>-14.9</td><td>+28.8</td><td>+44.5</td><td>+30.7</td></tr><tr><th>2019</th><td>+94.9</td><td>+88.3</td><td>+50.8</td></tr><tr><th>2020</th><td>+81.9</td><td>+32.6</td></tr><tr><th>2021</th><td>-3.3</td></tr>

# %%
# Create Round Trip Tear Sheet
# It generates ValueError: Axis limits cannot be NaN or Inf, that stops processing of rest of the code

returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(result)
pf.create_round_trip_tear_sheet(returns, positions, transactions, sector_mappings=sect_map)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Summary stats</th>
#       <th>All trades</th>
#       <th>Long trades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Total number of round_trips</th>
#       <td>13.00</td>
#       <td>13.00</td>
#     </tr>
#     <tr>
#       <th>Percent profitable</th>
#       <td>1.00</td>
#       <td>1.00</td>
#     </tr>
#     <tr>
#       <th>Winning round_trips</th>
#       <td>13.00</td>
#       <td>13.00</td>
#     </tr>
#     <tr>
#       <th>Losing round_trips</th>
#       <td>0.00</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>Even round_trips</th>
#       <td>0.00</td>
#       <td>0.00</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>PnL stats</th>
#       <th>All trades</th>
#       <th>Long trades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Total profit</th>
#       <td>$403325.94</td>
#       <td>$403325.94</td>
#     </tr>
#     <tr>
#       <th>Gross profit</th>
#       <td>$403325.94</td>
#       <td>$403325.94</td>
#     </tr>
#     <tr>
#       <th>Gross loss</th>
#       <td>$0.00</td>
#       <td>$0.00</td>
#     </tr>
#     <tr>
#       <th>Profit factor</th>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Avg. trade net profit</th>
#       <td>$31025.07</td>
#       <td>$31025.07</td>
#     </tr>
#     <tr>
#       <th>Avg. winning trade</th>
#       <td>$31025.07</td>
#       <td>$31025.07</td>
#     </tr>
#     <tr>
#       <th>Avg. losing trade</th>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Ratio Avg. Win:Avg. Loss</th>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Largest winning trade</th>
#       <td>$285157.76</td>
#       <td>$285157.76</td>
#     </tr>
#     <tr>
#       <th>Largest losing trade</th>
#       <td>$547.61</td>
#       <td>$547.61</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Duration stats</th>
#       <th>All trades</th>
#       <th>Long trades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avg duration</th>
#       <td>2311 days 02:18:27.846153856</td>
#       <td>2311 days 02:18:27.846153856</td>
#     </tr>
#     <tr>
#       <th>Median duration</th>
#       <td>2500 days 00:00:00</td>
#       <td>2500 days 00:00:00</td>
#     </tr>
#     <tr>
#       <th>Longest duration</th>
#       <td>3803 days 03:00:01</td>
#       <td>3803 days 03:00:01</td>
#     </tr>
#     <tr>
#       <th>Shortest duration</th>
#       <td>308 days 00:00:00</td>
#       <td>308 days 00:00:00</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Return stats</th>
#       <th>All trades</th>
#       <th>Long trades</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avg returns all round_trips</th>
#       <td>12.58%</td>
#       <td>12.58%</td>
#     </tr>
#     <tr>
#       <th>Avg returns winning</th>
#       <td>12.58%</td>
#       <td>12.58%</td>
#     </tr>
#     <tr>
#       <th>Avg returns losing</th>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Median returns all round_trips</th>
#       <td>6.00%</td>
#       <td>6.00%</td>
#     </tr>
#     <tr>
#       <th>Median returns winning</th>
#       <td>6.00%</td>
#       <td>6.00%</td>
#     </tr>
#     <tr>
#       <th>Median returns losing</th>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Largest winning trade</th>
#       <td>72.26%</td>
#       <td>72.26%</td>
#     </tr>
#     <tr>
#       <th>Largest losing trade</th>
#       <td>2.48%</td>
#       <td>2.48%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Symbol stats</th>
#       <th>TMF</th>
#       <th>TQQQ</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avg returns all round_trips</th>
#       <td>9.49%</td>
#       <td>13.94%</td>
#     </tr>
#     <tr>
#       <th>Avg returns winning</th>
#       <td>9.49%</td>
#       <td>13.94%</td>
#     </tr>
#     <tr>
#       <th>Avg returns losing</th>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Median returns all round_trips</th>
#       <td>7.96%</td>
#       <td>5.18%</td>
#     </tr>
#     <tr>
#       <th>Median returns winning</th>
#       <td>7.96%</td>
#       <td>5.18%</td>
#     </tr>
#     <tr>
#       <th>Median returns losing</th>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Largest winning trade</th>
#       <td>18.22%</td>
#       <td>72.26%</td>
#     </tr>
#     <tr>
#       <th>Largest losing trade</th>
#       <td>3.84%</td>
#       <td>2.48%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Profitability (PnL / PnL total) per name</th>
#       <th></th>
#     </tr>
#     <tr>
#       <th>symbol</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>TQQQ</th>
#       <td>95.52%</td>
#     </tr>
#     <tr>
#       <th>TMF</th>
#       <td>4.48%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Profitability (PnL / PnL total) per name</th>
#       <th></th>
#     </tr>
#     <tr>
#       <th>symbol</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>No Sector Mapping</th>
#       <td>100.00%</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-44a4ec0a24e0> in <module>
#       3
#       4 returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(result)
# ----> 5 pf.create_round_trip_tear_sheet(returns, positions, transactions, sector_mappings=sect_map)
#
# /opt/anaconda3/envs/zipreload/lib/python3.8/site-packages/pyfolio/plotting.py in call_w_context(*args, **kwargs)
#      48         if set_context:
#      49             with plotting_context(), axes_style():
# ---> 50                 return func(*args, **kwargs)
#      51         else:
#      52             return func(*args, **kwargs)
#
# /opt/anaconda3/envs/zipreload/lib/python3.8/site-packages/pyfolio/tears.py in create_round_trip_tear_sheet(returns, positions, transactions, sector_mappings, estimate_intraday, return_fig)
#     928     plotting.plot_round_trip_lifetimes(trades, ax=ax_trade_lifetimes)
#     929
# --> 930     plotting.plot_prob_profit_trade(trades, ax=ax_prob_profit_trade)
#     931
#     932     trade_holding_times = [x.days for x in trades["duration"]]
#
# /opt/anaconda3/envs/zipreload/lib/python3.8/site-packages/pyfolio/plotting.py in plot_prob_profit_trade(round_trips, ax)
#    2001     ax.set_xlabel("Probability of making a profitable decision")
#    2002     ax.set_ylabel("Belief")
# -> 2003     ax.set_xlim(lower_plot, upper_plot)
#    2004     ax.set_ylim((0, y.max() + 1.0))
#    2005
#
# /opt/anaconda3/envs/zipreload/lib/python3.8/site-packages/matplotlib/axes/_base.py in set_xlim(self, left, right, emit, auto, xmin, xmax)
#    3292
#    3293         self._process_unit_info(xdata=(left, right))
# -> 3294         left = self._validate_converted_limits(left, self.convert_xunits)
#    3295         right = self._validate_converted_limits(right, self.convert_xunits)
#    3296
#
# /opt/anaconda3/envs/zipreload/lib/python3.8/site-packages/matplotlib/axes/_base.py in _validate_converted_limits(self, limit, convert)
#    3209             if (isinstance(converted_limit, Real)
#    3210                     and not np.isfinite(converted_limit)):
# -> 3211                 raise ValueError("Axis limits cannot be NaN or Inf")
#    3212             return converted_limit
#    3213
#
# ValueError: Axis limits cannot be NaN or Inf
